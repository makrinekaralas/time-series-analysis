# %%
# %reset
import sys
sys.path.append('../')
import numpy as np
import pandas as pd
import datetime
from tsf_bmw.uvtsf import UVariateTimeSeriesForecaster
from tsf_bmw.tools import moving_linreg
from plotly.plotly import plot_mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors
# %matplotlib inline
from random import sample
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %% [markdown]
# ##### Read in the data

# %%
try:
    ts_univ = pd.read_pickle( '../data/pos_h.pkl' )
    print ( "====================================\nData: data of shape " + str(ts_univ.shape) + " has been read in." ) 
except IOError as e:
    print("Could not read in the data: {}".format(e))
# Out:
# ====================================
# Data: data of shape (705, 1) has been read in.

# %%
ts_univ.plot()

# %% [markdown]
# ##### Create UVariateTimeSeriesForecaster

# %%
uv_tsf = UVariateTimeSeriesForecaster(dict({'ts_df':ts_univ, 'time_format': "%Y-%m-%d %H:%M:%S", 'freq':'H', 'p_train':1.0}))
uv_tsf.ts_resample()
plt.plot(uv_tsf.ts_df)
# Out:
# Using time series data of range: 2018-09-04 08:00:00 - 2019-06-05 21:00:00 and shape: (705, 1)
# The object is initialized!
# Timse series resampled at frequency: <Hour>. New shape of data: (6590, 1)

# %%
#uv_tsf.ts_decompose(params=dict({'model':'additive'}))
uv_tsf.plot_decompose()

# %%
fittedvalues, slopes = moving_linreg(uvtsf_obj=uv_tsf, hist='2W', step='3D') #hist='2D', step='1D'
# Out:
# Starting moving linreg....
# moving linreg done!

# %%
method='auto_arima'
dict_params = dict()
dict_params = {
    'd': 0,
}

# %%
method = 'prophet'
dict_params = {
    'interval_width': 0.95,
    'yearly_seasonality': False,
    'weekly_seasonality': False,
    'daily_seasonality': False,
    'weekend_seasonality': False,
    'changepoint_prior_scale': 0.001
}

# %%
if len(dict_params):
    uv_tsf.ts_fit ( method=method, dict_params=dict_params ) 
else:
    uv_tsf.ts_fit ( method=method )
# Out:
# Trying to fit the Prophet model....
# ...via using parameters
#
#                              0
# interval_width            0.95
# yearly_seasonality       False
# weekly_seasonality       False
# daily_seasonality        False
# weekend_seasonality      False
# changepoint_prior_scale  0.001
# country                     AT
# state                     None
# consider_holidays         True
# changepoint_range          0.9
# add_change_points         True
# Considering holidays for country AT:
#
#             ds              holiday  lower_window  upper_window
# 0   2018-01-01              Neujahr             0             0
# 1   2018-01-06  Heilige Drei Könige             0             0
# 2   2018-04-02          Ostermontag             0             0
# 3   2018-05-01       Staatsfeiertag             0             0
# 4   2018-05-10  Christi Himmelfahrt             0             0
# 5   2018-05-21        Pfingstmontag             0             0
# 6   2018-05-31         Fronleichnam             0             0
# 7   2018-08-15    Maria Himmelfahrt             0             0
# 8   2018-10-26     Nationalfeiertag             0             0
# 9   2018-11-01        Allerheiligen             0             0
# 10  2018-12-08     Maria Empfängnis             0             0
# 11  2018-12-25            Christtag             0             0
# 12  2018-12-26           Stefanitag             0             0
# 13  2019-01-01              Neujahr             0             0
# 14  2019-01-06  Heilige Drei Könige             0             0
# 15  2019-04-22          Ostermontag             0             0
# 16  2019-05-01       Staatsfeiertag             0             0
# 17  2019-05-30  Christi Himmelfahrt             0             0
# 18  2019-06-10        Pfingstmontag             0             0
# 19  2019-06-20         Fronleichnam             0             0
# 20  2019-08-15    Maria Himmelfahrt             0             0
# 21  2019-10-26     Nationalfeiertag             0             0
# 22  2019-11-01        Allerheiligen             0             0
# 23  2019-12-08     Maria Empfängnis             0             0
# 24  2019-12-25            Christtag             0             0
# 25  2019-12-26           Stefanitag             0             0
# Time elapsed: 21.379596710205078
# Holidays included:
#
# 0                 Neujahr
# 1     Heilige Drei Könige
# 2             Ostermontag
# 3          Staatsfeiertag
# 4     Christi Himmelfahrt
# 5           Pfingstmontag
# 6            Fronleichnam
# 7       Maria Himmelfahrt
# 8        Nationalfeiertag
# 9           Allerheiligen
# 10       Maria Empfängnis
# 11              Christtag
# 12             Stefanitag
# dtype: object
# Model successfully fitted to the data!
# C:\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %%
uv_tsf.diagnose()

# %%
uv_tsf.plot_residuals()

# %%
uv_tsf.ts_test()
# Out:
# Nothing to validate. Call ts_forecast() or specify amount of training data when initializing the object.

# %%
uv_tsf.ts_forecast(n_forecast = 3*24)
# Out:
# Fitting using all data....
# Trying to fit the Prophet model....
# ...via using parameters
#
#                              0
# interval_width            0.95
# yearly_seasonality       False
# weekly_seasonality       False
# daily_seasonality        False
# weekend_seasonality      False
# changepoint_prior_scale  0.001
# country                     AT
# state                     None
# consider_holidays         True
# changepoint_range          0.9
# add_change_points         True
# Considering holidays for country AT:
#
#             ds              holiday  lower_window  upper_window
# 0   2018-01-01              Neujahr             0             0
# 1   2018-01-06  Heilige Drei Könige             0             0
# 2   2018-04-02          Ostermontag             0             0
# 3   2018-05-01       Staatsfeiertag             0             0
# 4   2018-05-10  Christi Himmelfahrt             0             0
# 5   2018-05-21        Pfingstmontag             0             0
# 6   2018-05-31         Fronleichnam             0             0
# 7   2018-08-15    Maria Himmelfahrt             0             0
# 8   2018-10-26     Nationalfeiertag             0             0
# 9   2018-11-01        Allerheiligen             0             0
# 10  2018-12-08     Maria Empfängnis             0             0
# 11  2018-12-25            Christtag             0             0
# 12  2018-12-26           Stefanitag             0             0
# 13  2019-01-01              Neujahr             0             0
# 14  2019-01-06  Heilige Drei Könige             0             0
# 15  2019-04-22          Ostermontag             0             0
# 16  2019-05-01       Staatsfeiertag             0             0
# 17  2019-05-30  Christi Himmelfahrt             0             0
# 18  2019-06-10        Pfingstmontag             0             0
# 19  2019-06-20         Fronleichnam             0             0
# 20  2019-08-15    Maria Himmelfahrt             0             0
# 21  2019-10-26     Nationalfeiertag             0             0
# 22  2019-11-01        Allerheiligen             0             0
# 23  2019-12-08     Maria Empfängnis             0             0
# 24  2019-12-25            Christtag             0             0
# 25  2019-12-26           Stefanitag             0             0
# Time elapsed: 21.12740421295166
# Holidays included:
#
# 0                 Neujahr
# 1     Heilige Drei Könige
# 2             Ostermontag
# 3          Staatsfeiertag
# 4     Christi Himmelfahrt
# 5           Pfingstmontag
# 6            Fronleichnam
# 7       Maria Himmelfahrt
# 8        Nationalfeiertag
# 9           Allerheiligen
# 10       Maria Empfängnis
# 11              Christtag
# 12             Stefanitag
# dtype: object
# Model successfully fitted to the data!
# Forecasting next 72H
